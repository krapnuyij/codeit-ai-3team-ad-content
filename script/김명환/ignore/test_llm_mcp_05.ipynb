# %% [markdown]
# ## 1. 환경 설정 및 임포트

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import asyncio
import logging
from pathlib import Path
from dotenv import load_dotenv
from helper_dev_utils import get_auto_logger
logger = get_auto_logger()

# 프로젝트 루트 경로 추가
project_root = Path.cwd().parent.parent
src_path = project_root / "src"

# sys.path에 추가
for path in [str(project_root), str(src_path)]:
    if path not in sys.path:
        sys.path.insert(0, path)
        logger.debug(f"path: {path}")

logger.debug(f"프로젝트 루트: {project_root}")
logger.debug(f"소스 경로: {src_path}")

# 환경 변수 로드
env_path = project_root / ".env"
if env_path.exists():
    load_dotenv(env_path)
    logger.debug(f"환경 변수 로드: {env_path}")
else:
    logger.warning(f".env 파일을 찾을 수 없습니다 ({env_path})")
# Out:
# 2026-01-09 16:56:56 W [helper_utils_colab:211] - GoogleDrive not found, falling back to temp folder: /tmp
# 2026-01-09 16:56:56 W [helper_utils_colab:122] - Cache directory not found, falling back to temp folder: /tmp
# 2026-01-09 16:56:56 D [ipykernel_launcher:18] - path: /home/spai0433/codeit-ai-3team-ad-content
# 2026-01-09 16:56:56 D [ipykernel_launcher:18] - path: /home/spai0433/codeit-ai-3team-ad-content/src
# 2026-01-09 16:56:56 D [ipykernel_launcher:20] - 프로젝트 루트: /home/spai0433/codeit-ai-3team-ad-content
# 2026-01-09 16:56:56 D [ipykernel_launcher:21] - 소스 경로: /home/spai0433/codeit-ai-3team-ad-content/src
# 2026-01-09 16:56:56 D [ipykernel_launcher:27] - 환경 변수 로드: /home/spai0433/codeit-ai-3team-ad-content/.env
# 2026-01-09 16:56:56 W [helper_utils_colab:122] - Cache directory not found, falling back to temp folder: /tmp
# 2026-01-09 16:56:56 D [ipykernel_launcher:18] - path: /home/spai0433/codeit-ai-3team-ad-content
# 2026-01-09 16:56:56 D [ipykernel_launcher:18] - path: /home/spai0433/codeit-ai-3team-ad-content/src
# 2026-01-09 16:56:56 D [ipykernel_launcher:20] - 프로젝트 루트: /home/spai0433/codeit-ai-3team-ad-content
# 2026-01-09 16:56:56 D [ipykernel_launcher:21] - 소스 경로: /home/spai0433/codeit-ai-3team-ad-content/src
# 2026-01-09 16:56:56 D [ipykernel_launcher:27] - 환경 변수 로드: /home/spai0433/codeit-ai-3team-ad-content/.env

# %% [markdown]
# ## 2. OpenAI API 키 확인

# %%
# OpenAI API 키 확인
openai_api_key = os.getenv("OPENAI_API_KEY")

if not openai_api_key:
    logger.debug("OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    logger.debug("   .env 파일에 다음을 추가하세요:")
    logger.debug("   OPENAI_API_KEY=sk-...")
else:
    logger.debug(f"OpenAI API 키 확인됨 (길이: {len(openai_api_key)} 문자)")
    logger.debug(f"   키 prefix: {openai_api_key[:5]} --- {openai_api_key[-5:]}")
# Out:
# 2026-01-09 16:56:56 D [ipykernel_launcher:9] - OpenAI API 키 확인됨 (길이: 164 문자)
# 2026-01-09 16:56:56 D [ipykernel_launcher:10] -    키 prefix: sk-pr --- cxzEA
# 2026-01-09 16:56:56 D [ipykernel_launcher:10] -    키 prefix: sk-pr --- cxzEA

# %% [markdown]
# ## 3. mcpadapter 임포트 및 초기화

# %%
# mcpadapter 임포트
from mcpadapter import MCPClient, LLMAdapter

# 설정
MCP_SERVER_URL = "http://localhost:3000"

logger.info("mcpadapter 임포트 완료")
logger.info(f"   MCP 서버 URL: {MCP_SERVER_URL}")
# Out:
# 2026-01-09 16:56:57 I [ipykernel_launcher:7] - mcpadapter 임포트 완료
# 2026-01-09 16:56:57 I [ipykernel_launcher:8] -    MCP 서버 URL: http://localhost:3000
# 2026-01-09 16:56:57 I [ipykernel_launcher:8] -    MCP 서버 URL: http://localhost:3000

# %% [markdown]
# ## 4. 이미지 경로 설정

# %%
# 이미지 파일 경로 설정
script_dir = Path.cwd()
product_image_path = script_dir / "image.png"
output_dir = script_dir / "outputs"
output_dir.mkdir(exist_ok=True)

# 출력 파일 경로
banana_output_path = output_dir / "banana_ad_result.png"

# 이미지 존재 확인
if product_image_path.exists():
    logger.info(f"제품 이미지 확인: {product_image_path}")
else:
    logger.warning(f"제품 이미지 없음: {product_image_path}")
    
logger.info(f"   출력 경로: {banana_output_path}")
# Out:
# 2026-01-09 16:56:57 I [ipykernel_launcher:12] - 제품 이미지 확인: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/image.png
# 2026-01-09 16:56:57 I [ipykernel_launcher:16] -    출력 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 16:56:57 I [ipykernel_launcher:16] -    출력 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png

# %% [markdown]
# ## 4-1. 서버 상태 대기 헬퍼 함수

# %%
async def wait_for_server_ready(max_wait_sec: int = 300, check_interval: int = 10) -> bool:
    """
    AI 서버가 idle 상태가 될 때까지 대기
    
    Args:
        max_wait_sec: 최대 대기 시간 (초, 기본값 300초 = 5분)
        check_interval: 상태 확인 간격 (초, 기본값 10초)
    
    Returns:
        True: 서버가 idle 상태
        False: 타임아웃 발생
    """
    logger.info(f"🕐 AI 서버 idle 상태 대기 중... (최대 {max_wait_sec}초)")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        elapsed = 0
        while elapsed < max_wait_sec:
            health = await client.call_tool("check_server_health", {})
            
            # health가 문자열인 경우 파싱
            if isinstance(health, str):
                # "상태: busy" 또는 "상태: idle" 패턴 찾기
                if "idle" in health.lower():
                    logger.info(f"   서버 idle 상태 확인 (대기 시간: {elapsed}초)")
                    return True
                elif "busy" in health.lower():
                    logger.info(f"   ⏳ 서버 busy 상태... {check_interval}초 후 재확인 (경과: {elapsed}초/{max_wait_sec}초)")
                else:
                    # 상태를 알 수 없으면 바로 진행
                    logger.warning(f"   서버 상태 불명: {health}")
                    return True
            else:
                # dict 형태인 경우
                status = health.get("status", "unknown") if isinstance(health, dict) else "unknown"
                if status == "idle":
                    logger.info(f"   서버 idle 상태 확인 (대기 시간: {elapsed}초)")
                    return True
                elif status == "busy":
                    logger.info(f"   ⏳ 서버 busy 상태... {check_interval}초 후 재확인 (경과: {elapsed}초/{max_wait_sec}초)")
                else:
                    logger.warning(f"   서버 상태: {status}")
                    return True
                
            await asyncio.sleep(check_interval)
            elapsed += check_interval
        
        logger.warning(f"   ⏰ 타임아웃: {max_wait_sec}초 동안 서버가 idle 상태가 되지 않음")
        return False

logger.info("서버 대기 헬퍼 함수 정의 완료")
# Out:
# 2026-01-09 16:56:57 I [ipykernel_launcher:53] - 서버 대기 헬퍼 함수 정의 완료

# %% [markdown]
# ## 7. 비동기 작업 패턴: Job ID 기반 폴링
#
# 대용량 작업의 경우 `wait_for_completion=False`로 설정하여 즉시 job_id를 받고, 상태를 주기적으로 확인할 수 있습니다.

# %%
# Step 1: 광고 생성 작업 시작 (job_id 반환)
async def start_ad_generation():
    """
    비동기 작업 시작: Job ID를 받아서 반환
    """
    logger.info("=" * 60)
    logger.info("Step 1: 광고 생성 작업 시작")
    logger.info("=" * 60)
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=600
    ) as client:
        
        # 모든 완료/실패 작업 정리
        logger.info("기존 완료/실패 작업 정리 중...")
        try:
            delete_result = await client.call_tool("delete_all_jobs", {})
            logger.info(f"작업 정리 결과:\n{delete_result}")
        except Exception as e:
            logger.warning(f"작업 정리 중 오류 (무시하고 계속): {e}")
        
        # 서버 상태 확인
        logger.info("서버 상태 확인 중...")
        try:
            health = await client.call_tool("check_server_health", {})
            logger.info(f"서버 상태: {health}")
            
            # busy 상태라면 대기
            if "busy" in str(health).lower():
                logger.info("서버가 busy 상태입니다. idle 대기 중...")
                is_ready = await wait_for_server_ready(max_wait_sec=300)
                if not is_ready:
                    logger.warning("서버가 여전히 busy 상태이지만 작업을 시도합니다.")
        except Exception as e:
            logger.warning(f"서버 상태 확인 중 오류 (무시하고 계속): {e}")
        
        params = {
            "product_image_path": str(product_image_path),
            "background_prompt": "Vibrant traditional Korean market scene, colorful fruit stalls, warm lighting",
            "text_content": "맛있는바나나 2500원 시장 자판",
            "text_style_prompt": "Bold 3D Korean text with yellow-gold gradient",
            "composition_mode": "overlay",
            "text_position": "center",
            "test_mode": False,
            "wait_for_completion": False,  # 즉시 job_id 반환
            "save_output_path": str(banana_output_path)
        }
        
        logger.info("광고 생성 요청 전송 중...")
        start_result = await client.call_tool("generate_ad_image", params)
        logger.info(f"Job 시작됨: {start_result}")
        
        # job_id 추출
        if isinstance(start_result, dict):
            job_id = start_result.get("job_id")
        elif isinstance(start_result, str):
            # 문자열 응답에서 job_id 추출
            import re
            match = re.search(r'작업 ID:\s*([a-f0-9\-]+)', start_result)
            if match:
                job_id = match.group(1)
            else:
                job_id = None
        else:
            job_id = None
        
        if not job_id:
            logger.warning("job_id를 찾을 수 없습니다. 동기 방식으로 처리된 것 같습니다.")
            return start_result
        
        logger.info(f"   Job ID: {job_id}")
        logger.info("   다음 셀에서 이 job_id로 상태를 확인하세요.")
        
        return job_id
        
# 실행
job_id = await start_ad_generation()
# Out:
# 2026-01-09 16:56:57 I [ipykernel_launcher:6] - ============================================================
# 2026-01-09 16:56:57 I [ipykernel_launcher:7] - Step 1: 광고 생성 작업 시작
# 2026-01-09 16:56:57 I [ipykernel_launcher:8] - ============================================================
# 2026-01-09 16:56:57 I [ipykernel_launcher:7] - Step 1: 광고 생성 작업 시작
# 2026-01-09 16:56:57 I [ipykernel_launcher:8] - ============================================================
# 2026-01-09 16:56:57 I [ipykernel_launcher:16] - 기존 완료/실패 작업 정리 중...
# 2026-01-09 16:56:57 I [ipykernel_launcher:16] - 기존 완료/실패 작업 정리 중...
# 2026-01-09 16:56:57 I [ipykernel_launcher:19] - 작업 정리 결과:
# 작업 삭제 중 에러 발생: 4 validation errors for JobListResponse
# jobs.0.elapsed_sec
#   Field required [type=missing, input_value={'job_id': '57feacf7-2db7...me': 1767940916.6774158}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.1.elapsed_sec
#   Field required [type=missing, input_value={'job_id': '05667e00-4f3e...me': 1767941160.2214537}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.2.elapsed_sec
#   Field required [type=missing, input_value={'job_id': 'ccb0c45d-8338...me': 1767943048.9614046}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.3.elapsed_sec
#   Field required [type=missing, input_value={'job_id': 'e0d192ff-62cd...me': 1767944075.0880148}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 2026-01-09 16:56:57 I [ipykernel_launcher:24] - 서버 상태 확인 중...
# 2026-01-09 16:56:57 I [ipykernel_launcher:19] - 작업 정리 결과:
# 작업 삭제 중 에러 발생: 4 validation errors for JobListResponse
# jobs.0.elapsed_sec
#   Field required [type=missing, input_value={'job_id': '57feacf7-2db7...me': 1767940916.6774158}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.1.elapsed_sec
#   Field required [type=missing, input_value={'job_id': '05667e00-4f3e...me': 1767941160.2214537}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.2.elapsed_sec
#   Field required [type=missing, input_value={'job_id': 'ccb0c45d-8338...me': 1767943048.9614046}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# jobs.3.elapsed_sec
#   Field required [type=missing, input_value={'job_id': 'e0d192ff-62cd...me': 1767944075.0880148}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.12/v/missing
# 2026-01-09 16:56:57 I [ipykernel_launcher:24] - 서버 상태 확인 중...
# 2026-01-09 16:56:57 I [ipykernel_launcher:27] - 서버 상태: 서버 상태: healthy
# 전체 작업: 4개
# 활성 작업: 0개
#
# 시스템 리소스:
#   CPU: 5.3%
#   RAM: 3.0/15.6 GB (19.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.5/22.5 GB
#
# 2026-01-09 16:56:57 I [ipykernel_launcher:50] - 광고 생성 요청 전송 중...
# 2026-01-09 16:56:57 I [ipykernel_launcher:27] - 서버 상태: 서버 상태: healthy
# 전체 작업: 4개
# 활성 작업: 0개
#
# 시스템 리소스:
#   CPU: 5.3%
#   RAM: 3.0/15.6 GB (19.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.5/22.5 GB
#
# 2026-01-09 16:56:57 I [ipykernel_launcher:50] - 광고 생성 요청 전송 중...
# 2026-01-09 16:57:11 I [ipykernel_launcher:52] - Job 시작됨: 작업 시작됨
# 작업 ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2
# 상태: started
#
# 진행 상태 확인: check_generation_status(job_id='0f0efe83-ace4-4448-9c30-5c8f089233d2')
# 2026-01-09 16:57:11 I [ipykernel_launcher:72] -    Job ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2
# 2026-01-09 16:57:11 I [ipykernel_launcher:73] -    다음 셀에서 이 job_id로 상태를 확인하세요.
# 2026-01-09 16:57:11 I [ipykernel_launcher:52] - Job 시작됨: 작업 시작됨
# 작업 ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2
# 상태: started
#
# 진행 상태 확인: check_generation_status(job_id='0f0efe83-ace4-4448-9c30-5c8f089233d2')
# 2026-01-09 16:57:11 I [ipykernel_launcher:72] -    Job ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2
# 2026-01-09 16:57:11 I [ipykernel_launcher:73] -    다음 셀에서 이 job_id로 상태를 확인하세요.

# %%
# Step 2: 작업 상태 조회 (폴링) - 완료 시 이미지 저장 포함
async def check_ad_generation_status(
    job_id: str, 
    save_result_path: str = None,
    max_attempts: int = 300, 
    interval: int = 10
):
    """
    Job ID로 작업 상태를 확인하고 완료 시 이미지를 저장
    
    Args:
        job_id: 확인할 작업 ID
        save_result_path: 완료 시 저장할 이미지 경로 (중요!)
        max_attempts: 최대 시도 횟수 (기본값: 30회)
        interval: 확인 간격 (초, 기본값: 10초)
    
    Returns:
        최종 상태 결과
    """
    logger.info("=" * 60)
    logger.info(f"Step 2: 작업 상태 확인 (Job ID: {job_id})")
    if save_result_path:
        logger.info(f"완료 시 저장 경로: {save_result_path}")
    logger.info("=" * 60)
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        
        attempt = 0
        while attempt < max_attempts:
            await asyncio.sleep(interval)
            attempt += 1
            
            # 상태 확인 (save_result_path 전달!)
            status_params = {"job_id": job_id}
            if save_result_path:
                status_params["save_result_path"] = save_result_path
            
            status_result = await client.call_tool(
                "check_generation_status",
                status_params
            )
            
            logger.info(f"   [{attempt}/{max_attempts}] 상태: {status_result}")
            
            # 완료 여부 확인
            if isinstance(status_result, dict):
                status = status_result.get("status")
                progress = status_result.get("progress", 0)
                
                if status == "completed":
                    logger.info("✅ 작업 완료!")
                    if save_result_path:
                        logger.info(f"   이미지 저장됨: {save_result_path}")
                    return status_result
                elif status == "failed":
                    logger.error(f"❌ 작업 실패: {status_result.get('error')}")
                    return status_result
                else:
                    logger.info(f"   진행 중... (진행률: {progress}%)")
            else:
                # 문자열 응답 처리
                if "completed" in str(status_result).lower():
                    logger.info("✅ 작업 완료!")
                    if save_result_path:
                        logger.info(f"   이미지 저장됨: {save_result_path}")
                    return status_result
                elif "failed" in str(status_result).lower():
                    logger.error(f"❌ 작업 실패: {status_result}")
                    return status_result
        
        logger.warning(f"⏰ 타임아웃: {max_attempts * interval}초 동안 작업이 완료되지 않음")
        return {"status": "timeout", "message": "작업이 제한 시간 내에 완료되지 않았습니다."}
        

# 실행 (job_id를 앞 셀에서 받아야 함)
if 'job_id' in dir() and job_id:
    status_result = await check_ad_generation_status(
        job_id, 
        save_result_path=str(banana_output_path)  # 저장 경로 전달!
    )
else:
    logger.warning("job_id가 없습니다. 먼저 이전 셀을 실행하세요.")
# Out:
# 2026-01-09 16:57:11 I [ipykernel_launcher:20] - ============================================================
# 2026-01-09 16:57:11 I [ipykernel_launcher:21] - Step 2: 작업 상태 확인 (Job ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2)
# 2026-01-09 16:57:11 I [ipykernel_launcher:23] - 완료 시 저장 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 16:57:11 I [ipykernel_launcher:24] - ============================================================
# 2026-01-09 16:57:11 I [ipykernel_launcher:21] - Step 2: 작업 상태 확인 (Job ID: 0f0efe83-ace4-4448-9c30-5c8f089233d2)
# 2026-01-09 16:57:11 I [ipykernel_launcher:23] - 완료 시 저장 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 16:57:11 I [ipykernel_launcher:24] - ============================================================
# 2026-01-09 16:57:21 I [ipykernel_launcher:46] -    [1/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 10.1초
# 예상 남은 시간: 522초
#
# 시스템 메트릭:
#   CPU: 20.6%
#   RAM: 4.7/15.6 GB (29.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:21 I [ipykernel_launcher:46] -    [1/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 10.1초
# 예상 남은 시간: 522초
#
# 시스템 메트릭:
#   CPU: 20.6%
#   RAM: 4.7/15.6 GB (29.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:31 I [ipykernel_launcher:46] -    [2/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 20.2초
# 예상 남은 시간: 512초
#
# 시스템 메트릭:
#   CPU: 14.0%
#   RAM: 5.1/15.6 GB (32.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:31 I [ipykernel_launcher:46] -    [2/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 20.2초
# 예상 남은 시간: 512초
#
# 시스템 메트릭:
#   CPU: 14.0%
#   RAM: 5.1/15.6 GB (32.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:41 I [ipykernel_launcher:46] -    [3/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 30.2초
# 예상 남은 시간: 502초
#
# 시스템 메트릭:
#   CPU: 14.8%
#   RAM: 5.7/15.6 GB (36.2%)
#   GPU 0 (NVIDIA L4): 3%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:41 I [ipykernel_launcher:46] -    [3/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 30.2초
# 예상 남은 시간: 502초
#
# 시스템 메트릭:
#   CPU: 14.8%
#   RAM: 5.7/15.6 GB (36.2%)
#   GPU 0 (NVIDIA L4): 3%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:51 I [ipykernel_launcher:46] -    [4/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 40.2초
# 예상 남은 시간: 492초
#
# 시스템 메트릭:
#   CPU: 17.8%
#   RAM: 6.1/15.6 GB (39.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:57:51 I [ipykernel_launcher:46] -    [4/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 40.2초
# 예상 남은 시간: 492초
#
# 시스템 메트릭:
#   CPU: 17.8%
#   RAM: 6.1/15.6 GB (39.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:58:01 I [ipykernel_launcher:46] -    [5/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 50.3초
# 예상 남은 시간: 482초
#
# 시스템 메트릭:
#   CPU: 16.4%
#   RAM: 6.6/15.6 GB (42.2%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:58:01 I [ipykernel_launcher:46] -    [5/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 50.3초
# 예상 남은 시간: 482초
#
# 시스템 메트릭:
#   CPU: 16.4%
#   RAM: 6.6/15.6 GB (42.2%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 16:58:11 I [ipykernel_launcher:46] -    [6/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 60.3초
# 예상 남은 시간: 472초
#
# 시스템 메트릭:
#   CPU: 15.6%
#   RAM: 7.1/15.6 GB (45.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 7.1/22.5 GB
#
# 2026-01-09 16:58:11 I [ipykernel_launcher:46] -    [6/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 60.3초
# 예상 남은 시간: 472초
#
# 시스템 메트릭:
#   CPU: 15.6%
#   RAM: 7.1/15.6 GB (45.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 7.1/22.5 GB
#
# 2026-01-09 16:58:22 I [ipykernel_launcher:46] -    [7/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 70.4초
# 예상 남은 시간: 462초
#
# 시스템 메트릭:
#   CPU: 17.6%
#   RAM: 6.7/15.6 GB (42.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 8.2/22.5 GB
#
# 2026-01-09 16:58:22 I [ipykernel_launcher:46] -    [7/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 70.4초
# 예상 남은 시간: 462초
#
# 시스템 메트릭:
#   CPU: 17.6%
#   RAM: 6.7/15.6 GB (42.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 8.2/22.5 GB
#
# 2026-01-09 16:58:32 I [ipykernel_launcher:46] -    [8/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 80.7초
# 예상 남은 시간: 452초
#
# 시스템 메트릭:
#   CPU: 18.8%
#   RAM: 4.9/15.6 GB (31.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 9.2/22.5 GB
#
# 2026-01-09 16:58:32 I [ipykernel_launcher:46] -    [8/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 80.7초
# 예상 남은 시간: 452초
#
# 시스템 메트릭:
#   CPU: 18.8%
#   RAM: 4.9/15.6 GB (31.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 9.2/22.5 GB
#
# 2026-01-09 16:58:42 I [ipykernel_launcher:46] -    [9/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 90.8초
# 예상 남은 시간: 442초
#
# 시스템 메트릭:
#   CPU: 18.2%
#   RAM: 4.6/15.6 GB (29.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 10.2/22.5 GB
#
# 2026-01-09 16:58:42 I [ipykernel_launcher:46] -    [9/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 90.8초
# 예상 남은 시간: 442초
#
# 시스템 메트릭:
#   CPU: 18.2%
#   RAM: 4.6/15.6 GB (29.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 10.2/22.5 GB
#
# 2026-01-09 16:58:52 I [ipykernel_launcher:46] -    [10/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 101.0초
# 예상 남은 시간: 432초
#
# 시스템 메트릭:
#   CPU: 17.5%
#   RAM: 4.7/15.6 GB (29.9%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 11.4/22.5 GB
#
# 2026-01-09 16:58:52 I [ipykernel_launcher:46] -    [10/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 101.0초
# 예상 남은 시간: 432초
#
# 시스템 메트릭:
#   CPU: 17.5%
#   RAM: 4.7/15.6 GB (29.9%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 11.4/22.5 GB
#
# 2026-01-09 16:59:02 I [ipykernel_launcher:46] -    [11/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 111.0초
# 예상 남은 시간: 421초
#
# 시스템 메트릭:
#   CPU: 10.3%
#   RAM: 4.9/15.6 GB (31.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 16:59:02 I [ipykernel_launcher:46] -    [11/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 111.0초
# 예상 남은 시간: 421초
#
# 시스템 메트릭:
#   CPU: 10.3%
#   RAM: 4.9/15.6 GB (31.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 16:59:12 I [ipykernel_launcher:46] -    [12/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 121.1초
# 예상 남은 시간: 411초
#
# 시스템 메트릭:
#   CPU: 7.8%
#   RAM: 5.1/15.6 GB (32.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 12.8/22.5 GB
#
# 2026-01-09 16:59:12 I [ipykernel_launcher:46] -    [12/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 121.1초
# 예상 남은 시간: 411초
#
# 시스템 메트릭:
#   CPU: 7.8%
#   RAM: 5.1/15.6 GB (32.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 12.8/22.5 GB
#
# 2026-01-09 16:59:22 I [ipykernel_launcher:46] -    [13/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 131.1초
# 예상 남은 시간: 401초
#
# 시스템 메트릭:
#   CPU: 7.0%
#   RAM: 5.0/15.6 GB (32.3%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 15.1/22.5 GB
#
# 2026-01-09 16:59:22 I [ipykernel_launcher:46] -    [13/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 131.1초
# 예상 남은 시간: 401초
#
# 시스템 메트릭:
#   CPU: 7.0%
#   RAM: 5.0/15.6 GB (32.3%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 15.1/22.5 GB
#
# 2026-01-09 16:59:32 I [ipykernel_launcher:46] -    [14/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 141.3초
# 예상 남은 시간: 391초
#
# 시스템 메트릭:
#   CPU: 7.5%
#   RAM: 5.0/15.6 GB (32.1%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 17.5/22.5 GB
#
# 2026-01-09 16:59:32 I [ipykernel_launcher:46] -    [14/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 141.3초
# 예상 남은 시간: 391초
#
# 시스템 메트릭:
#   CPU: 7.5%
#   RAM: 5.0/15.6 GB (32.1%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 17.5/22.5 GB
#
# 2026-01-09 16:59:42 I [ipykernel_launcher:46] -    [15/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 151.4초
# 예상 남은 시간: 381초
#
# 시스템 메트릭:
#   CPU: 7.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 19.9/22.5 GB
#
# 2026-01-09 16:59:42 I [ipykernel_launcher:46] -    [15/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 151.4초
# 예상 남은 시간: 381초
#
# 시스템 메트릭:
#   CPU: 7.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 19.9/22.5 GB
#
# 2026-01-09 16:59:52 I [ipykernel_launcher:46] -    [16/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 161.4초
# 예상 남은 시간: 371초
#
# 시스템 메트릭:
#   CPU: 8.4%
#   RAM: 4.9/15.6 GB (31.6%)
#   GPU 0 (NVIDIA L4): 86%, VRAM: 21.4/22.5 GB
#
# 2026-01-09 16:59:52 I [ipykernel_launcher:46] -    [16/300] 상태: 작업 상태: running
# 진행률: 0%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 161.4초
# 예상 남은 시간: 371초
#
# 시스템 메트릭:
#   CPU: 8.4%
#   RAM: 4.9/15.6 GB (31.6%)
#   GPU 0 (NVIDIA L4): 86%, VRAM: 21.4/22.5 GB
#
# 2026-01-09 17:00:02 I [ipykernel_launcher:46] -    [17/300] 상태: 작업 상태: running
# 진행률: 2%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 171.5초
# 예상 남은 시간: 516초
#
# 시스템 메트릭:
#   CPU: 26.3%
#   RAM: 4.9/15.6 GB (31.6%)
#   GPU 0 (NVIDIA L4): 87%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:02 I [ipykernel_launcher:46] -    [17/300] 상태: 작업 상태: running
# 진행률: 2%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 171.5초
# 예상 남은 시간: 516초
#
# 시스템 메트릭:
#   CPU: 26.3%
#   RAM: 4.9/15.6 GB (31.6%)
#   GPU 0 (NVIDIA L4): 87%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:12 I [ipykernel_launcher:46] -    [18/300] 상태: 작업 상태: running
# 진행률: 5%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 181.5초
# 예상 남은 시간: 498초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 5.0/15.6 GB (31.8%)
#   GPU 0 (NVIDIA L4): 96%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:12 I [ipykernel_launcher:46] -    [18/300] 상태: 작업 상태: running
# 진행률: 5%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 181.5초
# 예상 남은 시간: 498초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 5.0/15.6 GB (31.8%)
#   GPU 0 (NVIDIA L4): 96%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:22 I [ipykernel_launcher:46] -    [19/300] 상태: 작업 상태: running
# 진행률: 7%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 191.6초
# 예상 남은 시간: 481초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.8%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:22 I [ipykernel_launcher:46] -    [19/300] 상태: 작업 상태: running
# 진행률: 7%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 191.6초
# 예상 남은 시간: 481초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.8%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:32 I [ipykernel_launcher:46] -    [20/300] 상태: 작업 상태: running
# 진행률: 10%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 201.6초
# 예상 남은 시간: 464초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:32 I [ipykernel_launcher:46] -    [20/300] 상태: 작업 상태: running
# 진행률: 10%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 201.6초
# 예상 남은 시간: 464초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:42 I [ipykernel_launcher:46] -    [21/300] 상태: 작업 상태: running
# 진행률: 13%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 211.7초
# 예상 남은 시간: 447초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 95%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:42 I [ipykernel_launcher:46] -    [21/300] 상태: 작업 상태: running
# 진행률: 13%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 211.7초
# 예상 남은 시간: 447초
#
# 시스템 메트릭:
#   CPU: 26.6%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 95%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:53 I [ipykernel_launcher:46] -    [22/300] 상태: 작업 상태: running
# 진행률: 15%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 221.7초
# 예상 남은 시간: 429초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:00:53 I [ipykernel_launcher:46] -    [22/300] 상태: 작업 상태: running
# 진행률: 15%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 221.7초
# 예상 남은 시간: 429초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 5.0/15.6 GB (31.9%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:01:03 I [ipykernel_launcher:46] -    [23/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 231.7초
# 예상 남은 시간: 418초
#
# 시스템 메트릭:
#   CPU: 25.4%
#   RAM: 11.4/15.6 GB (73.1%)
#   GPU 0 (NVIDIA L4): 9%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:01:03 I [ipykernel_launcher:46] -    [23/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 231.7초
# 예상 남은 시간: 418초
#
# 시스템 메트릭:
#   CPU: 25.4%
#   RAM: 11.4/15.6 GB (73.1%)
#   GPU 0 (NVIDIA L4): 9%, VRAM: 21.6/22.5 GB
#
# 2026-01-09 17:01:13 I [ipykernel_launcher:46] -    [24/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 241.8초
# 예상 남은 시간: 408초
#
# 시스템 메트릭:
#   CPU: 13.2%
#   RAM: 12.0/15.6 GB (77.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.0/22.5 GB
#
# 2026-01-09 17:01:13 I [ipykernel_launcher:46] -    [24/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 241.8초
# 예상 남은 시간: 408초
#
# 시스템 메트릭:
#   CPU: 13.2%
#   RAM: 12.0/15.6 GB (77.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.0/22.5 GB
#
# 2026-01-09 17:01:23 I [ipykernel_launcher:46] -    [25/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 251.8초
# 예상 남은 시간: 398초
#
# 시스템 메트릭:
#   CPU: 7.7%
#   RAM: 12.1/15.6 GB (77.6%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 14.1/22.5 GB
#
# 2026-01-09 17:01:23 I [ipykernel_launcher:46] -    [25/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 251.8초
# 예상 남은 시간: 398초
#
# 시스템 메트릭:
#   CPU: 7.7%
#   RAM: 12.1/15.6 GB (77.6%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 14.1/22.5 GB
#
# 2026-01-09 17:01:33 I [ipykernel_launcher:46] -    [26/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 261.8초
# 예상 남은 시간: 388초
#
# 시스템 메트릭:
#   CPU: 11.3%
#   RAM: 11.1/15.6 GB (70.8%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 16.2/22.5 GB
#
# 2026-01-09 17:01:33 I [ipykernel_launcher:46] -    [26/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 261.8초
# 예상 남은 시간: 388초
#
# 시스템 메트릭:
#   CPU: 11.3%
#   RAM: 11.1/15.6 GB (70.8%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 16.2/22.5 GB
#
# 2026-01-09 17:01:43 I [ipykernel_launcher:46] -    [27/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 272.0초
# 예상 남은 시간: 378초
#
# 시스템 메트릭:
#   CPU: 13.3%
#   RAM: 9.3/15.6 GB (59.5%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 18.1/22.5 GB
#
# 2026-01-09 17:01:43 I [ipykernel_launcher:46] -    [27/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 272.0초
# 예상 남은 시간: 378초
#
# 시스템 메트릭:
#   CPU: 13.3%
#   RAM: 9.3/15.6 GB (59.5%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 18.1/22.5 GB
#
# 2026-01-09 17:01:53 I [ipykernel_launcher:46] -    [28/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 282.1초
# 예상 남은 시간: 367초
#
# 시스템 메트릭:
#   CPU: 9.9%
#   RAM: 7.5/15.6 GB (48.0%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 20.0/22.5 GB
#
# 2026-01-09 17:01:53 I [ipykernel_launcher:46] -    [28/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 282.1초
# 예상 남은 시간: 367초
#
# 시스템 메트릭:
#   CPU: 9.9%
#   RAM: 7.5/15.6 GB (48.0%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 20.0/22.5 GB
#
# 2026-01-09 17:02:03 I [ipykernel_launcher:46] -    [29/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 292.2초
# 예상 남은 시간: 357초
#
# 시스템 메트릭:
#   CPU: 13.6%
#   RAM: 9.2/15.6 GB (59.2%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:03 I [ipykernel_launcher:46] -    [29/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 292.2초
# 예상 남은 시간: 357초
#
# 시스템 메트릭:
#   CPU: 13.6%
#   RAM: 9.2/15.6 GB (59.2%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:13 I [ipykernel_launcher:46] -    [30/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 302.2초
# 예상 남은 시간: 347초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 10.8/15.6 GB (68.9%)
#   GPU 0 (NVIDIA L4): 10%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:13 I [ipykernel_launcher:46] -    [30/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 302.2초
# 예상 남은 시간: 347초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 10.8/15.6 GB (68.9%)
#   GPU 0 (NVIDIA L4): 10%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:23 I [ipykernel_launcher:46] -    [31/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 312.3초
# 예상 남은 시간: 337초
#
# 시스템 메트릭:
#   CPU: 16.2%
#   RAM: 11.0/15.6 GB (70.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:23 I [ipykernel_launcher:46] -    [31/300] 상태: 작업 상태: running
# 진행률: 16%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 312.3초
# 예상 남은 시간: 337초
#
# 시스템 메트릭:
#   CPU: 16.2%
#   RAM: 11.0/15.6 GB (70.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:02:33 I [ipykernel_launcher:46] -    [32/300] 상태: 작업 상태: running
# 진행률: 17%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 322.6초
# 예상 남은 시간: 421초
#
# 시스템 메트릭:
#   CPU: 17.8%
#   RAM: 10.7/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 93%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:02:33 I [ipykernel_launcher:46] -    [32/300] 상태: 작업 상태: running
# 진행률: 17%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 322.6초
# 예상 남은 시간: 421초
#
# 시스템 메트릭:
#   CPU: 17.8%
#   RAM: 10.7/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 93%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:02:44 I [ipykernel_launcher:46] -    [33/300] 상태: 작업 상태: running
# 진행률: 20%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 332.7초
# 예상 남은 시간: 404초
#
# 시스템 메트릭:
#   CPU: 27.6%
#   RAM: 10.6/15.6 GB (68.2%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:02:44 I [ipykernel_launcher:46] -    [33/300] 상태: 작업 상태: running
# 진행률: 20%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 332.7초
# 예상 남은 시간: 404초
#
# 시스템 메트릭:
#   CPU: 27.6%
#   RAM: 10.6/15.6 GB (68.2%)
#   GPU 0 (NVIDIA L4): 94%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:02:54 I [ipykernel_launcher:46] -    [34/300] 상태: 작업 상태: running
# 진행률: 22%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 342.7초
# 예상 남은 시간: 389초
#
# 시스템 메트릭:
#   CPU: 26.7%
#   RAM: 10.7/15.6 GB (68.2%)
#   GPU 0 (NVIDIA L4): 88%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:02:54 I [ipykernel_launcher:46] -    [34/300] 상태: 작업 상태: running
# 진행률: 22%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 342.7초
# 예상 남은 시간: 389초
#
# 시스템 메트릭:
#   CPU: 26.7%
#   RAM: 10.7/15.6 GB (68.2%)
#   GPU 0 (NVIDIA L4): 88%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:03:04 I [ipykernel_launcher:46] -    [35/300] 상태: 작업 상태: running
# 진행률: 24%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 352.8초
# 예상 남은 시간: 374초
#
# 시스템 메트릭:
#   CPU: 26.5%
#   RAM: 10.7/15.6 GB (68.3%)
#   GPU 0 (NVIDIA L4): 86%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:03:04 I [ipykernel_launcher:46] -    [35/300] 상태: 작업 상태: running
# 진행률: 24%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 352.8초
# 예상 남은 시간: 374초
#
# 시스템 메트릭:
#   CPU: 26.5%
#   RAM: 10.7/15.6 GB (68.3%)
#   GPU 0 (NVIDIA L4): 86%, VRAM: 13.5/22.5 GB
#
# 2026-01-09 17:03:14 I [ipykernel_launcher:46] -    [36/300] 상태: 작업 상태: running
# 진행률: 26%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 362.8초
# 예상 남은 시간: 360초
#
# 시스템 메트릭:
#   CPU: 21.1%
#   RAM: 10.7/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 14.8/22.5 GB
#
# 2026-01-09 17:03:14 I [ipykernel_launcher:46] -    [36/300] 상태: 작업 상태: running
# 진행률: 26%
# 현재 단계: step1_background
# 메시지: Step 1: Generating Background... (배경 이미지 생성 중)
# 경과 시간: 362.8초
# 예상 남은 시간: 360초
#
# 시스템 메트릭:
#   CPU: 21.1%
#   RAM: 10.7/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 14.8/22.5 GB
#
# 2026-01-09 17:03:24 I [ipykernel_launcher:46] -    [37/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 372.9초
# 예상 남은 시간: 350초
#
# 시스템 메트릭:
#   CPU: 5.3%
#   RAM: 11.0/15.6 GB (70.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:24 I [ipykernel_launcher:46] -    [37/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 372.9초
# 예상 남은 시간: 350초
#
# 시스템 메트릭:
#   CPU: 5.3%
#   RAM: 11.0/15.6 GB (70.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:34 I [ipykernel_launcher:46] -    [38/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 383.2초
# 예상 남은 시간: 340초
#
# 시스템 메트릭:
#   CPU: 6.8%
#   RAM: 11.4/15.6 GB (73.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:34 I [ipykernel_launcher:46] -    [38/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 383.2초
# 예상 남은 시간: 340초
#
# 시스템 메트릭:
#   CPU: 6.8%
#   RAM: 11.4/15.6 GB (73.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:44 I [ipykernel_launcher:46] -    [39/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 393.3초
# 예상 남은 시간: 330초
#
# 시스템 메트릭:
#   CPU: 11.9%
#   RAM: 12.3/15.6 GB (79.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:44 I [ipykernel_launcher:46] -    [39/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 393.3초
# 예상 남은 시간: 330초
#
# 시스템 메트릭:
#   CPU: 11.9%
#   RAM: 12.3/15.6 GB (79.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:54 I [ipykernel_launcher:46] -    [40/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 403.5초
# 예상 남은 시간: 320초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 11.6/15.6 GB (74.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:03:54 I [ipykernel_launcher:46] -    [40/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 403.5초
# 예상 남은 시간: 320초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 11.6/15.6 GB (74.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:05 I [ipykernel_launcher:46] -    [41/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 414.1초
# 예상 남은 시간: 309초
#
# 시스템 메트릭:
#   CPU: 11.1%
#   RAM: 11.0/15.6 GB (70.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:05 I [ipykernel_launcher:46] -    [41/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 414.1초
# 예상 남은 시간: 309초
#
# 시스템 메트릭:
#   CPU: 11.1%
#   RAM: 11.0/15.6 GB (70.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:16 I [ipykernel_launcher:46] -    [42/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 424.5초
# 예상 남은 시간: 299초
#
# 시스템 메트릭:
#   CPU: 13.2%
#   RAM: 10.2/15.6 GB (65.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:16 I [ipykernel_launcher:46] -    [42/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 424.5초
# 예상 남은 시간: 299초
#
# 시스템 메트릭:
#   CPU: 13.2%
#   RAM: 10.2/15.6 GB (65.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:26 I [ipykernel_launcher:46] -    [43/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 434.8초
# 예상 남은 시간: 288초
#
# 시스템 메트릭:
#   CPU: 14.9%
#   RAM: 8.8/15.6 GB (56.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:26 I [ipykernel_launcher:46] -    [43/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 434.8초
# 예상 남은 시간: 288초
#
# 시스템 메트릭:
#   CPU: 14.9%
#   RAM: 8.8/15.6 GB (56.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:37 I [ipykernel_launcher:46] -    [44/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 445.3초
# 예상 남은 시간: 278초
#
# 시스템 메트릭:
#   CPU: 24.4%
#   RAM: 8.5/15.6 GB (54.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:37 I [ipykernel_launcher:46] -    [44/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 445.3초
# 예상 남은 시간: 278초
#
# 시스템 메트릭:
#   CPU: 24.4%
#   RAM: 8.5/15.6 GB (54.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:48 I [ipykernel_launcher:46] -    [45/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 456.8초
# 예상 남은 시간: 266초
#
# 시스템 메트릭:
#   CPU: 21.6%
#   RAM: 7.0/15.6 GB (44.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:48 I [ipykernel_launcher:46] -    [45/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 456.8초
# 예상 남은 시간: 266초
#
# 시스템 메트릭:
#   CPU: 21.6%
#   RAM: 7.0/15.6 GB (44.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:59 I [ipykernel_launcher:46] -    [46/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 467.0초
# 예상 남은 시간: 256초
#
# 시스템 메트릭:
#   CPU: 18.6%
#   RAM: 7.5/15.6 GB (48.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:04:59 I [ipykernel_launcher:46] -    [46/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 467.0초
# 예상 남은 시간: 256초
#
# 시스템 메트릭:
#   CPU: 18.6%
#   RAM: 7.5/15.6 GB (48.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:10 I [ipykernel_launcher:46] -    [47/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 479.0초
# 예상 남은 시간: 244초
#
# 시스템 메트릭:
#   CPU: 15.5%
#   RAM: 6.2/15.6 GB (39.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:10 I [ipykernel_launcher:46] -    [47/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 479.0초
# 예상 남은 시간: 244초
#
# 시스템 메트릭:
#   CPU: 15.5%
#   RAM: 6.2/15.6 GB (39.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:20 I [ipykernel_launcher:46] -    [48/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 489.3초
# 예상 남은 시간: 234초
#
# 시스템 메트릭:
#   CPU: 10.5%
#   RAM: 5.5/15.6 GB (35.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:20 I [ipykernel_launcher:46] -    [48/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 489.3초
# 예상 남은 시간: 234초
#
# 시스템 메트릭:
#   CPU: 10.5%
#   RAM: 5.5/15.6 GB (35.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:30 I [ipykernel_launcher:46] -    [49/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 499.4초
# 예상 남은 시간: 224초
#
# 시스템 메트릭:
#   CPU: 11.0%
#   RAM: 6.1/15.6 GB (39.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:30 I [ipykernel_launcher:46] -    [49/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 499.4초
# 예상 남은 시간: 224초
#
# 시스템 메트릭:
#   CPU: 11.0%
#   RAM: 6.1/15.6 GB (39.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:05:40 I [ipykernel_launcher:46] -    [50/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 509.6초
# 예상 남은 시간: 214초
#
# 시스템 메트릭:
#   CPU: 5.7%
#   RAM: 6.7/15.6 GB (42.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.2/22.5 GB
#
# 2026-01-09 17:05:40 I [ipykernel_launcher:46] -    [50/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 509.6초
# 예상 남은 시간: 214초
#
# 시스템 메트릭:
#   CPU: 5.7%
#   RAM: 6.7/15.6 GB (42.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.2/22.5 GB
#
# 2026-01-09 17:05:51 I [ipykernel_launcher:46] -    [51/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 519.7초
# 예상 남은 시간: 204초
#
# 시스템 메트릭:
#   CPU: 4.8%
#   RAM: 7.0/15.6 GB (45.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.7/22.5 GB
#
# 2026-01-09 17:05:51 I [ipykernel_launcher:46] -    [51/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 519.7초
# 예상 남은 시간: 204초
#
# 시스템 메트릭:
#   CPU: 4.8%
#   RAM: 7.0/15.6 GB (45.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 12.7/22.5 GB
#
# 2026-01-09 17:06:01 I [ipykernel_launcher:46] -    [52/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 529.8초
# 예상 남은 시간: 193초
#
# 시스템 메트릭:
#   CPU: 4.7%
#   RAM: 7.0/15.6 GB (45.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 13.2/22.5 GB
#
# 2026-01-09 17:06:01 I [ipykernel_launcher:46] -    [52/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 529.8초
# 예상 남은 시간: 193초
#
# 시스템 메트릭:
#   CPU: 4.7%
#   RAM: 7.0/15.6 GB (45.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 13.2/22.5 GB
#
# 2026-01-09 17:06:11 I [ipykernel_launcher:46] -    [53/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 539.9초
# 예상 남은 시간: 183초
#
# 시스템 메트릭:
#   CPU: 4.0%
#   RAM: 7.0/15.6 GB (45.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 13.6/22.5 GB
#
# 2026-01-09 17:06:11 I [ipykernel_launcher:46] -    [53/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 539.9초
# 예상 남은 시간: 183초
#
# 시스템 메트릭:
#   CPU: 4.0%
#   RAM: 7.0/15.6 GB (45.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 13.6/22.5 GB
#
# 2026-01-09 17:06:21 I [ipykernel_launcher:46] -    [54/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 550.3초
# 예상 남은 시간: 173초
#
# 시스템 메트릭:
#   CPU: 5.5%
#   RAM: 7.0/15.6 GB (44.7%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 14.1/22.5 GB
#
# 2026-01-09 17:06:21 I [ipykernel_launcher:46] -    [54/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 550.3초
# 예상 남은 시간: 173초
#
# 시스템 메트릭:
#   CPU: 5.5%
#   RAM: 7.0/15.6 GB (44.7%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 14.1/22.5 GB
#
# 2026-01-09 17:06:31 I [ipykernel_launcher:46] -    [55/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 560.4초
# 예상 남은 시간: 163초
#
# 시스템 메트릭:
#   CPU: 5.3%
#   RAM: 7.0/15.6 GB (44.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 15.8/22.5 GB
#
# 2026-01-09 17:06:31 I [ipykernel_launcher:46] -    [55/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 560.4초
# 예상 남은 시간: 163초
#
# 시스템 메트릭:
#   CPU: 5.3%
#   RAM: 7.0/15.6 GB (44.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 15.8/22.5 GB
#
# 2026-01-09 17:06:41 I [ipykernel_launcher:46] -    [56/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 570.5초
# 예상 남은 시간: 153초
#
# 시스템 메트릭:
#   CPU: 4.9%
#   RAM: 7.5/15.6 GB (47.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 16.3/22.5 GB
#
# 2026-01-09 17:06:41 I [ipykernel_launcher:46] -    [56/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 570.5초
# 예상 남은 시간: 153초
#
# 시스템 메트릭:
#   CPU: 4.9%
#   RAM: 7.5/15.6 GB (47.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 16.3/22.5 GB
#
# 2026-01-09 17:06:52 I [ipykernel_launcher:46] -    [57/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 580.6초
# 예상 남은 시간: 143초
#
# 시스템 메트릭:
#   CPU: 4.1%
#   RAM: 8.0/15.6 GB (51.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 16.8/22.5 GB
#
# 2026-01-09 17:06:52 I [ipykernel_launcher:46] -    [57/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 580.6초
# 예상 남은 시간: 143초
#
# 시스템 메트릭:
#   CPU: 4.1%
#   RAM: 8.0/15.6 GB (51.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 16.8/22.5 GB
#
# 2026-01-09 17:07:02 I [ipykernel_launcher:46] -    [58/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 590.7초
# 예상 남은 시간: 133초
#
# 시스템 메트릭:
#   CPU: 4.2%
#   RAM: 8.5/15.6 GB (54.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 17.3/22.5 GB
#
# 2026-01-09 17:07:02 I [ipykernel_launcher:46] -    [58/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 590.7초
# 예상 남은 시간: 133초
#
# 시스템 메트릭:
#   CPU: 4.2%
#   RAM: 8.5/15.6 GB (54.2%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 17.3/22.5 GB
#
# 2026-01-09 17:07:12 I [ipykernel_launcher:46] -    [59/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 600.8초
# 예상 남은 시간: 122초
#
# 시스템 메트릭:
#   CPU: 4.0%
#   RAM: 8.9/15.6 GB (57.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 17.8/22.5 GB
#
# 2026-01-09 17:07:12 I [ipykernel_launcher:46] -    [59/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 600.8초
# 예상 남은 시간: 122초
#
# 시스템 메트릭:
#   CPU: 4.0%
#   RAM: 8.9/15.6 GB (57.3%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 17.8/22.5 GB
#
# 2026-01-09 17:07:22 I [ipykernel_launcher:46] -    [60/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 610.8초
# 예상 남은 시간: 112초
#
# 시스템 메트릭:
#   CPU: 3.4%
#   RAM: 9.4/15.6 GB (60.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 18.3/22.5 GB
#
# 2026-01-09 17:07:22 I [ipykernel_launcher:46] -    [60/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 610.8초
# 예상 남은 시간: 112초
#
# 시스템 메트릭:
#   CPU: 3.4%
#   RAM: 9.4/15.6 GB (60.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 18.3/22.5 GB
#
# 2026-01-09 17:07:32 I [ipykernel_launcher:46] -    [61/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 620.9초
# 예상 남은 시간: 102초
#
# 시스템 메트릭:
#   CPU: 4.8%
#   RAM: 9.8/15.6 GB (62.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 20.1/22.5 GB
#
# 2026-01-09 17:07:32 I [ipykernel_launcher:46] -    [61/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 620.9초
# 예상 남은 시간: 102초
#
# 시스템 메트릭:
#   CPU: 4.8%
#   RAM: 9.8/15.6 GB (62.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 20.1/22.5 GB
#
# 2026-01-09 17:07:42 I [ipykernel_launcher:46] -    [62/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 631.0초
# 예상 남은 시간: 92초
#
# 시스템 메트릭:
#   CPU: 4.1%
#   RAM: 10.3/15.6 GB (65.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 20.6/22.5 GB
#
# 2026-01-09 17:07:42 I [ipykernel_launcher:46] -    [62/300] 상태: 작업 상태: running
# 진행률: 33%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 631.0초
# 예상 남은 시간: 92초
#
# 시스템 메트릭:
#   CPU: 4.1%
#   RAM: 10.3/15.6 GB (65.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 20.6/22.5 GB
#
# 2026-01-09 17:07:52 I [ipykernel_launcher:46] -    [63/300] 상태: 작업 상태: running
# 진행률: 46%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 641.0초
# 예상 남은 시간: 257초
#
# 시스템 메트릭:
#   CPU: 19.0%
#   RAM: 10.4/15.6 GB (66.5%)
#   GPU 0 (NVIDIA L4): 100%, VRAM: 21.4/22.5 GB
#
# 2026-01-09 17:07:52 I [ipykernel_launcher:46] -    [63/300] 상태: 작업 상태: running
# 진행률: 46%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 641.0초
# 예상 남은 시간: 257초
#
# 시스템 메트릭:
#   CPU: 19.0%
#   RAM: 10.4/15.6 GB (66.5%)
#   GPU 0 (NVIDIA L4): 100%, VRAM: 21.4/22.5 GB
#
# 2026-01-09 17:08:02 I [ipykernel_launcher:46] -    [64/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 651.1초
# 예상 남은 시간: 160초
#
# 시스템 메트릭:
#   CPU: 25.5%
#   RAM: 10.4/15.6 GB (66.4%)
#   GPU 0 (NVIDIA L4): 38%, VRAM: 22.3/22.5 GB
#
# 2026-01-09 17:08:02 I [ipykernel_launcher:46] -    [64/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 651.1초
# 예상 남은 시간: 160초
#
# 시스템 메트릭:
#   CPU: 25.5%
#   RAM: 10.4/15.6 GB (66.4%)
#   GPU 0 (NVIDIA L4): 38%, VRAM: 22.3/22.5 GB
#
# 2026-01-09 17:08:12 I [ipykernel_launcher:46] -    [65/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 661.2초
# 예상 남은 시간: 149초
#
# 시스템 메트릭:
#   CPU: 5.1%
#   RAM: 10.6/15.6 GB (67.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 22.3/22.5 GB
#
# 2026-01-09 17:08:12 I [ipykernel_launcher:46] -    [65/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 661.2초
# 예상 남은 시간: 149초
#
# 시스템 메트릭:
#   CPU: 5.1%
#   RAM: 10.6/15.6 GB (67.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 22.3/22.5 GB
#
# 2026-01-09 17:08:22 I [ipykernel_launcher:46] -    [66/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 671.3초
# 예상 남은 시간: 139초
#
# 시스템 메트릭:
#   CPU: 10.5%
#   RAM: 10.7/15.6 GB (68.6%)
#   GPU 0 (NVIDIA L4): 100%, VRAM: 13.8/22.5 GB
#
# 2026-01-09 17:08:22 I [ipykernel_launcher:46] -    [66/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step2_text
# 메시지: Step 2: Generating 3D Text... (3D 텍스트 생성 중)
# 경과 시간: 671.3초
# 예상 남은 시간: 139초
#
# 시스템 메트릭:
#   CPU: 10.5%
#   RAM: 10.7/15.6 GB (68.6%)
#   GPU 0 (NVIDIA L4): 100%, VRAM: 13.8/22.5 GB
#
# 2026-01-09 17:08:32 I [ipykernel_launcher:46] -    [67/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 681.3초
# 예상 남은 시간: 129초
#
# 시스템 메트릭:
#   CPU: 11.7%
#   RAM: 10.8/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 2026-01-09 17:08:32 I [ipykernel_launcher:46] -    [67/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 681.3초
# 예상 남은 시간: 129초
#
# 시스템 메트릭:
#   CPU: 11.7%
#   RAM: 10.8/15.6 GB (68.8%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 2026-01-09 17:08:43 I [ipykernel_launcher:46] -    [68/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 691.7초
# 예상 남은 시간: 119초
#
# 시스템 메트릭:
#   CPU: 14.6%
#   RAM: 10.9/15.6 GB (69.6%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:08:43 I [ipykernel_launcher:46] -    [68/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 691.7초
# 예상 남은 시간: 119초
#
# 시스템 메트릭:
#   CPU: 14.6%
#   RAM: 10.9/15.6 GB (69.6%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:08:53 I [ipykernel_launcher:46] -    [69/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 701.8초
# 예상 남은 시간: 109초
#
# 시스템 메트릭:
#   CPU: 14.9%
#   RAM: 10.9/15.6 GB (69.8%)
#   GPU 0 (NVIDIA L4): 4%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:08:53 I [ipykernel_launcher:46] -    [69/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 701.8초
# 예상 남은 시간: 109초
#
# 시스템 메트릭:
#   CPU: 14.9%
#   RAM: 10.9/15.6 GB (69.8%)
#   GPU 0 (NVIDIA L4): 4%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:03 I [ipykernel_launcher:46] -    [70/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 711.9초
# 예상 남은 시간: 99초
#
# 시스템 메트릭:
#   CPU: 16.4%
#   RAM: 9.3/15.6 GB (59.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:03 I [ipykernel_launcher:46] -    [70/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 711.9초
# 예상 남은 시간: 99초
#
# 시스템 메트릭:
#   CPU: 16.4%
#   RAM: 9.3/15.6 GB (59.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:13 I [ipykernel_launcher:46] -    [71/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 722.1초
# 예상 남은 시간: 89초
#
# 시스템 메트릭:
#   CPU: 17.2%
#   RAM: 7.3/15.6 GB (47.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:13 I [ipykernel_launcher:46] -    [71/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 722.1초
# 예상 남은 시간: 89초
#
# 시스템 메트릭:
#   CPU: 17.2%
#   RAM: 7.3/15.6 GB (47.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:23 I [ipykernel_launcher:46] -    [72/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 732.3초
# 예상 남은 시간: 78초
#
# 시스템 메트릭:
#   CPU: 12.9%
#   RAM: 7.2/15.6 GB (46.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:23 I [ipykernel_launcher:46] -    [72/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 732.3초
# 예상 남은 시간: 78초
#
# 시스템 메트릭:
#   CPU: 12.9%
#   RAM: 7.2/15.6 GB (46.1%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.3/22.5 GB
#
# 2026-01-09 17:09:33 I [ipykernel_launcher:46] -    [73/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 742.4초
# 예상 남은 시간: 68초
#
# 시스템 메트릭:
#   CPU: 14.8%
#   RAM: 5.6/15.6 GB (36.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.8/22.5 GB
#
# 2026-01-09 17:09:33 I [ipykernel_launcher:46] -    [73/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 742.4초
# 예상 남은 시간: 68초
#
# 시스템 메트릭:
#   CPU: 14.8%
#   RAM: 5.6/15.6 GB (36.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 6.8/22.5 GB
#
# 2026-01-09 17:09:44 I [ipykernel_launcher:46] -    [74/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 752.6초
# 예상 남은 시간: 58초
#
# 시스템 메트릭:
#   CPU: 15.0%
#   RAM: 5.8/15.6 GB (36.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 7.8/22.5 GB
#
# 2026-01-09 17:09:44 I [ipykernel_launcher:46] -    [74/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 752.6초
# 예상 남은 시간: 58초
#
# 시스템 메트릭:
#   CPU: 15.0%
#   RAM: 5.8/15.6 GB (36.9%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 7.8/22.5 GB
#
# 2026-01-09 17:09:54 I [ipykernel_launcher:46] -    [75/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 762.7초
# 예상 남은 시간: 48초
#
# 시스템 메트릭:
#   CPU: 16.3%
#   RAM: 4.8/15.6 GB (31.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 8.8/22.5 GB
#
# 2026-01-09 17:09:54 I [ipykernel_launcher:46] -    [75/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 762.7초
# 예상 남은 시간: 48초
#
# 시스템 메트릭:
#   CPU: 16.3%
#   RAM: 4.8/15.6 GB (31.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 8.8/22.5 GB
#
# 2026-01-09 17:10:04 I [ipykernel_launcher:46] -    [76/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 772.9초
# 예상 남은 시간: 38초
#
# 시스템 메트릭:
#   CPU: 14.1%
#   RAM: 5.2/15.6 GB (33.5%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 9.7/22.5 GB
#
# 2026-01-09 17:10:04 I [ipykernel_launcher:46] -    [76/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 772.9초
# 예상 남은 시간: 38초
#
# 시스템 메트릭:
#   CPU: 14.1%
#   RAM: 5.2/15.6 GB (33.5%)
#   GPU 0 (NVIDIA L4): 7%, VRAM: 9.7/22.5 GB
#
# 2026-01-09 17:10:14 I [ipykernel_launcher:46] -    [77/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 783.1초
# 예상 남은 시간: 28초
#
# 시스템 메트릭:
#   CPU: 14.7%
#   RAM: 5.4/15.6 GB (34.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 10.8/22.5 GB
#
# 2026-01-09 17:10:14 I [ipykernel_launcher:46] -    [77/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 783.1초
# 예상 남은 시간: 28초
#
# 시스템 메트릭:
#   CPU: 14.7%
#   RAM: 5.4/15.6 GB (34.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 10.8/22.5 GB
#
# 2026-01-09 17:10:24 I [ipykernel_launcher:46] -    [78/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 793.3초
# 예상 남은 시간: 17초
#
# 시스템 메트릭:
#   CPU: 15.7%
#   RAM: 5.2/15.6 GB (33.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.8/22.5 GB
#
# 2026-01-09 17:10:24 I [ipykernel_launcher:46] -    [78/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 793.3초
# 예상 남은 시간: 17초
#
# 시스템 메트릭:
#   CPU: 15.7%
#   RAM: 5.2/15.6 GB (33.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.8/22.5 GB
#
# 2026-01-09 17:10:34 I [ipykernel_launcher:46] -    [79/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 803.4초
# 예상 남은 시간: 7초
#
# 시스템 메트릭:
#   CPU: 8.3%
#   RAM: 5.4/15.6 GB (34.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 12.0/22.5 GB
#
# 2026-01-09 17:10:34 I [ipykernel_launcher:46] -    [79/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 803.4초
# 예상 남은 시간: 7초
#
# 시스템 메트릭:
#   CPU: 8.3%
#   RAM: 5.4/15.6 GB (34.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 12.0/22.5 GB
#
# 2026-01-09 17:10:45 I [ipykernel_launcher:46] -    [80/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 813.7초
# 예상 시간 초과: 2초
#
# 시스템 메트릭:
#   CPU: 9.1%
#   RAM: 4.7/15.6 GB (30.0%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:10:45 I [ipykernel_launcher:46] -    [80/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 813.7초
# 예상 시간 초과: 2초
#
# 시스템 메트릭:
#   CPU: 9.1%
#   RAM: 4.7/15.6 GB (30.0%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:10:55 I [ipykernel_launcher:46] -    [81/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 824.5초
# 예상 시간 초과: 13초
#
# 시스템 메트릭:
#   CPU: 7.1%
#   RAM: 4.7/15.6 GB (30.1%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 15.8/22.5 GB
#
# 2026-01-09 17:10:55 I [ipykernel_launcher:46] -    [81/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 824.5초
# 예상 시간 초과: 13초
#
# 시스템 메트릭:
#   CPU: 7.1%
#   RAM: 4.7/15.6 GB (30.1%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 15.8/22.5 GB
#
# 2026-01-09 17:11:06 I [ipykernel_launcher:46] -    [82/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 834.6초
# 예상 시간 초과: 23초
#
# 시스템 메트릭:
#   CPU: 7.9%
#   RAM: 4.6/15.6 GB (29.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 18.2/22.5 GB
#
# 2026-01-09 17:11:06 I [ipykernel_launcher:46] -    [82/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 834.6초
# 예상 시간 초과: 23초
#
# 시스템 메트릭:
#   CPU: 7.9%
#   RAM: 4.6/15.6 GB (29.7%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 18.2/22.5 GB
#
# 2026-01-09 17:11:16 I [ipykernel_launcher:46] -    [83/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 844.7초
# 예상 시간 초과: 33초
#
# 시스템 메트릭:
#   CPU: 7.2%
#   RAM: 4.6/15.6 GB (29.6%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 20.6/22.5 GB
#
# 2026-01-09 17:11:16 I [ipykernel_launcher:46] -    [83/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 844.7초
# 예상 시간 초과: 33초
#
# 시스템 메트릭:
#   CPU: 7.2%
#   RAM: 4.6/15.6 GB (29.6%)
#   GPU 0 (NVIDIA L4): 2%, VRAM: 20.6/22.5 GB
#
# 2026-01-09 17:11:26 I [ipykernel_launcher:46] -    [84/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 854.8초
# 예상 시간 초과: 43초
#
# 시스템 메트릭:
#   CPU: 7.4%
#   RAM: 5.5/15.6 GB (34.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:26 I [ipykernel_launcher:46] -    [84/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 854.8초
# 예상 시간 초과: 43초
#
# 시스템 메트릭:
#   CPU: 7.4%
#   RAM: 5.5/15.6 GB (34.9%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:36 I [ipykernel_launcher:46] -    [85/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 865.0초
# 예상 시간 초과: 53초
#
# 시스템 메트릭:
#   CPU: 6.5%
#   RAM: 6.7/15.6 GB (42.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:36 I [ipykernel_launcher:46] -    [85/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 865.0초
# 예상 시간 초과: 53초
#
# 시스템 메트릭:
#   CPU: 6.5%
#   RAM: 6.7/15.6 GB (42.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:46 I [ipykernel_launcher:46] -    [86/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 875.1초
# 예상 시간 초과: 63초
#
# 시스템 메트릭:
#   CPU: 6.8%
#   RAM: 8.0/15.6 GB (51.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:46 I [ipykernel_launcher:46] -    [86/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 875.1초
# 예상 시간 초과: 63초
#
# 시스템 메트릭:
#   CPU: 6.8%
#   RAM: 8.0/15.6 GB (51.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:57 I [ipykernel_launcher:46] -    [87/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 885.2초
# 예상 시간 초과: 74초
#
# 시스템 메트릭:
#   CPU: 11.1%
#   RAM: 9.7/15.6 GB (62.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:11:57 I [ipykernel_launcher:46] -    [87/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 885.2초
# 예상 시간 초과: 74초
#
# 시스템 메트릭:
#   CPU: 11.1%
#   RAM: 9.7/15.6 GB (62.0%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:12:07 I [ipykernel_launcher:46] -    [88/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 895.8초
# 예상 시간 초과: 84초
#
# 시스템 메트릭:
#   CPU: 7.6%
#   RAM: 10.8/15.6 GB (69.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:12:07 I [ipykernel_launcher:46] -    [88/300] 상태: 작업 상태: running
# 진행률: 66%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 895.8초
# 예상 시간 초과: 84초
#
# 시스템 메트릭:
#   CPU: 7.6%
#   RAM: 10.8/15.6 GB (69.4%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 21.0/22.5 GB
#
# 2026-01-09 17:12:17 I [ipykernel_launcher:46] -    [89/300] 상태: 작업 상태: running
# 진행률: 67%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 906.0초
# 예상 남은 시간: 154초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 12.0/15.6 GB (76.6%)
#   GPU 0 (NVIDIA L4): 81%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:17 I [ipykernel_launcher:46] -    [89/300] 상태: 작업 상태: running
# 진행률: 67%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 906.0초
# 예상 남은 시간: 154초
#
# 시스템 메트릭:
#   CPU: 17.4%
#   RAM: 12.0/15.6 GB (76.6%)
#   GPU 0 (NVIDIA L4): 81%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:27 I [ipykernel_launcher:46] -    [90/300] 상태: 작업 상태: running
# 진행률: 72%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 916.1초
# 예상 남은 시간: 130초
#
# 시스템 메트릭:
#   CPU: 28.3%
#   RAM: 12.0/15.6 GB (76.9%)
#   GPU 0 (NVIDIA L4): 90%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:27 I [ipykernel_launcher:46] -    [90/300] 상태: 작업 상태: running
# 진행률: 72%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 916.1초
# 예상 남은 시간: 130초
#
# 시스템 메트릭:
#   CPU: 28.3%
#   RAM: 12.0/15.6 GB (76.9%)
#   GPU 0 (NVIDIA L4): 90%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:37 I [ipykernel_launcher:46] -    [91/300] 상태: 작업 상태: running
# 진행률: 76%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 926.2초
# 예상 남은 시간: 107초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 12.0/15.6 GB (76.9%)
#   GPU 0 (NVIDIA L4): 95%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:37 I [ipykernel_launcher:46] -    [91/300] 상태: 작업 상태: running
# 진행률: 76%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 926.2초
# 예상 남은 시간: 107초
#
# 시스템 메트릭:
#   CPU: 26.9%
#   RAM: 12.0/15.6 GB (76.9%)
#   GPU 0 (NVIDIA L4): 95%, VRAM: 13.3/22.5 GB
#
# 2026-01-09 17:12:47 I [ipykernel_launcher:46] -    [92/300] 상태: 작업 상태: running
# 진행률: 80%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 936.3초
# 예상 남은 시간: 87초
#
# 시스템 메트릭:
#   CPU: 20.4%
#   RAM: 12.2/15.6 GB (78.3%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 13.8/22.5 GB
#
# 2026-01-09 17:12:47 I [ipykernel_launcher:46] -    [92/300] 상태: 작업 상태: running
# 진행률: 80%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 936.3초
# 예상 남은 시간: 87초
#
# 시스템 메트릭:
#   CPU: 20.4%
#   RAM: 12.2/15.6 GB (78.3%)
#   GPU 0 (NVIDIA L4): 1%, VRAM: 13.8/22.5 GB
#
# 2026-01-09 17:12:57 I [ipykernel_launcher:46] -    [93/300] 상태: 작업 상태: running
# 진행률: 80%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 946.5초
# 예상 남은 시간: 77초
#
# 시스템 메트릭:
#   CPU: 3.4%
#   RAM: 12.4/15.6 GB (79.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:12:57 I [ipykernel_launcher:46] -    [93/300] 상태: 작업 상태: running
# 진행률: 80%
# 현재 단계: step3_composite
# 메시지: Step 3: Intelligent Compositing... (지능형 합성 중)
# 경과 시간: 946.5초
# 예상 남은 시간: 77초
#
# 시스템 메트릭:
#   CPU: 3.4%
#   RAM: 12.4/15.6 GB (79.6%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 11.9/22.5 GB
#
# 2026-01-09 17:13:08 I [ipykernel_launcher:46] -    [94/300] 상태: 작업 상태: completed
# 진행률: 100%
# 현재 단계: step3_composite
# 메시지: All steps completed successfully.
# 경과 시간: 956.6초
# 예상 남은 시간: 92초
#
# 시스템 메트릭:
#   CPU: 8.7%
#   RAM: 6.5/15.6 GB (41.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 작업 완료!
# 저장 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 17:13:08 I [ipykernel_launcher:66] - ✅ 작업 완료!
# 2026-01-09 17:13:08 I [ipykernel_launcher:68] -    이미지 저장됨: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 17:13:08 I [ipykernel_launcher:46] -    [94/300] 상태: 작업 상태: completed
# 진행률: 100%
# 현재 단계: step3_composite
# 메시지: All steps completed successfully.
# 경과 시간: 956.6초
# 예상 남은 시간: 92초
#
# 시스템 메트릭:
#   CPU: 8.7%
#   RAM: 6.5/15.6 GB (41.5%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 작업 완료!
# 저장 경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 17:13:08 I [ipykernel_launcher:66] - ✅ 작업 완료!
# 2026-01-09 17:13:08 I [ipykernel_launcher:68] -    이미지 저장됨: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png

# %%
from IPython.display import Image, display

# Step 3: 결과 확인 및 출력
def display_ad_result():
    """
    생성된 광고 이미지 확인 및 표시
    """
    logger.info("=" * 60)
    logger.info("Step 3: 결과 확인 및 출력")
    logger.info("=" * 60)
    
    if banana_output_path.exists():
        file_size = banana_output_path.stat().st_size
        logger.info(f"✅ 광고 이미지 생성 완료!")
        logger.info(f"   경로: {banana_output_path}")
        logger.info(f"   크기: {file_size:,} bytes ({file_size / 1024:.1f} KB)")
        logger.info("이미지 표시:")
        display(Image(filename=str(banana_output_path)))
        
    else:
        logger.error(f"❌ 출력 이미지를 찾을 수 없습니다: {banana_output_path}")
        logger.info("확인사항:")
        logger.info(f"   1. 작업이 정상 완료되었는지 확인")
        logger.info(f"   2. 출력 디렉토리 존재 여부: {output_dir.exists()}")
        if output_dir.exists():
            files = list(output_dir.glob("*"))
            logger.info(f"   3. 출력 디렉토리 파일 목록: {files}")

# 실행
display_ad_result()
# Out:
# 2026-01-09 17:13:11 I [ipykernel_launcher:8] - ============================================================
# 2026-01-09 17:13:11 I [ipykernel_launcher:9] - Step 3: 결과 확인 및 출력
# 2026-01-09 17:13:11 I [ipykernel_launcher:10] - ============================================================
# 2026-01-09 17:13:11 I [ipykernel_launcher:14] - ✅ 광고 이미지 생성 완료!
# 2026-01-09 17:13:11 I [ipykernel_launcher:15] -    경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 17:13:11 I [ipykernel_launcher:16] -    크기: 1,663,907 bytes (1624.9 KB)
# 2026-01-09 17:13:11 I [ipykernel_launcher:17] - 이미지 표시:
# 2026-01-09 17:13:11 I [ipykernel_launcher:9] - Step 3: 결과 확인 및 출력
# 2026-01-09 17:13:11 I [ipykernel_launcher:10] - ============================================================
# 2026-01-09 17:13:11 I [ipykernel_launcher:14] - ✅ 광고 이미지 생성 완료!
# 2026-01-09 17:13:11 I [ipykernel_launcher:15] -    경로: /home/spai0433/codeit-ai-3team-ad-content/script/김명환/outputs/banana_ad_result.png
# 2026-01-09 17:13:11 I [ipykernel_launcher:16] -    크기: 1,663,907 bytes (1624.9 KB)
# 2026-01-09 17:13:11 I [ipykernel_launcher:17] - 이미지 표시:

# %%
# 간단한 테스트: 서버 상태 확인
async def quick_test():
    """MCP 서버 연결 및 상태 확인"""
    logger.info("=== 빠른 연결 테스트 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # 서버 상태 확인
        health = await client.call_tool("check_server_health", {})
        logger.info(f"서버 상태:\n{health}")
        
        # 폰트 목록 확인
        fonts = await client.call_tool("list_available_fonts", {})
        logger.info(f"사용 가능한 폰트:\n{fonts}")
        
    logger.info("=== 테스트 완료 ===")

await quick_test()
# Out:
# 2026-01-09 17:13:12 I [ipykernel_launcher:4] - === 빠른 연결 테스트 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:12] - 서버 상태:
# 서버 상태: healthy
# 전체 작업: 5개
# 활성 작업: 0개
#
# 시스템 리소스:
#   CPU: 14.0%
#   RAM: 6.7/15.6 GB (42.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 2026-01-09 17:13:12 I [ipykernel_launcher:16] - 사용 가능한 폰트:
# 사용 가능한 폰트 (54개):
#
#   - D2coding/D2CodingLigature/D2Coding-Ver1.3.2-20180524-ligature.ttf
#   - D2coding/D2CodingLigature/D2CodingBold-Ver1.3.2-20180524-ligature.ttf
#   - NanumSquareNeo/NanumSquareNeo/NanumSquareNeo-Variable.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-aLt.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-bRg.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-cBd.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-dEb.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-eHv.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicBold.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicExtraBold.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicLight.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEco.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEcoBold.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEcoExtraBold.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjo.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjoBold.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjoExtraBold.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEco.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEcoBold.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEcoExtraBold.ttf
#   - 나눔명조옛한글/NanumMyeongjo-YetHangul.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicBold.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicLight.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicUltraLight.ttf
#   - 나눔바른고딕옛한글/NanumBarunGothic-YetHangul.ttf
#   - 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenB.ttf
#   - 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenR.ttf
#   - 나눔손글씨_붓/NanumBrush.ttf
#   - 나눔손글씨_펜/NanumPen.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareEB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareL.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareR.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acEB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acL.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acR.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundB.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundEB.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundL.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundR.ttf
#   - 나눔휴먼/NanumHumanBold.ttf
#   - 나눔휴먼/NanumHumanEB.ttf
#   - 나눔휴먼/NanumHumanEL.ttf
#   - 나눔휴먼/NanumHumanHeavy.ttf
#   - 나눔휴먼/NanumHumanLight.ttf
#   - 나눔휴먼/NanumHumanRegular.ttf
#   - 마루 부리/MaruBuri-Bold.ttf
#   - 마루 부리/MaruBuri-ExtraLight.ttf
#   - 마루 부리/MaruBuri-Light.ttf
#   - 마루 부리/MaruBuri-Regular.ttf
#   - 마루 부리/MaruBuri-SemiBold.ttf
#
# 2026-01-09 17:13:12 I [ipykernel_launcher:18] - === 테스트 완료 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:12] - 서버 상태:
# 서버 상태: healthy
# 전체 작업: 5개
# 활성 작업: 0개
#
# 시스템 리소스:
#   CPU: 14.0%
#   RAM: 6.7/15.6 GB (42.7%)
#   GPU 0 (NVIDIA L4): 0%, VRAM: 0.7/22.5 GB
#
# 2026-01-09 17:13:12 I [ipykernel_launcher:16] - 사용 가능한 폰트:
# 사용 가능한 폰트 (54개):
#
#   - D2coding/D2CodingLigature/D2Coding-Ver1.3.2-20180524-ligature.ttf
#   - D2coding/D2CodingLigature/D2CodingBold-Ver1.3.2-20180524-ligature.ttf
#   - NanumSquareNeo/NanumSquareNeo/NanumSquareNeo-Variable.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-aLt.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-bRg.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-cBd.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-dEb.ttf
#   - NanumSquareNeo/NanumSquareNeo/TTF/NanumSquareNeo-eHv.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothic.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicBold.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicExtraBold.ttf
#   - 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicLight.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEco.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEcoBold.ttf
#   - 나눔고딕에코/NanumFontSetup_TTF_GOTHICECO/NanumGothicEcoExtraBold.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjo.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjoBold.ttf
#   - 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjoExtraBold.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEco.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEcoBold.ttf
#   - 나눔명조에코/NanumFontSetup_TTF_MYUNGJOECO/NanumMyeongjoEcoExtraBold.ttf
#   - 나눔명조옛한글/NanumMyeongjo-YetHangul.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothic.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicBold.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicLight.ttf
#   - 나눔바른고딕/NanumFontSetup_TTF_BARUNGOTHIC/NanumBarunGothicUltraLight.ttf
#   - 나눔바른고딕옛한글/NanumBarunGothic-YetHangul.ttf
#   - 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenB.ttf
#   - 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenR.ttf
#   - 나눔손글씨_붓/NanumBrush.ttf
#   - 나눔손글씨_펜/NanumPen.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareEB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareL.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquareR.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acEB.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acL.ttf
#   - 나눔스퀘어/NanumFontSetup_TTF_SQUARE/NanumSquare_acR.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundB.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundEB.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundL.ttf
#   - 나눔스퀘어라운드/NanumFontSetup_TTF_SQUARE_ROUND/NanumSquareRoundR.ttf
#   - 나눔휴먼/NanumHumanBold.ttf
#   - 나눔휴먼/NanumHumanEB.ttf
#   - 나눔휴먼/NanumHumanEL.ttf
#   - 나눔휴먼/NanumHumanHeavy.ttf
#   - 나눔휴먼/NanumHumanLight.ttf
#   - 나눔휴먼/NanumHumanRegular.ttf
#   - 마루 부리/MaruBuri-Bold.ttf
#   - 마루 부리/MaruBuri-ExtraLight.ttf
#   - 마루 부리/MaruBuri-Light.ttf
#   - 마루 부리/MaruBuri-Regular.ttf
#   - 마루 부리/MaruBuri-SemiBold.ttf
#
# 2026-01-09 17:13:12 I [ipykernel_launcher:18] - === 테스트 완료 ===

# %% [markdown]
# ## 폰트 자동 선택 테스트

# %%
# 1. 폰트 메타데이터 조회
async def test_font_metadata():
    """폰트 메타데이터 조회 테스트"""
    logger.info("=== 폰트 메타데이터 조회 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # 폰트 메타데이터 조회
        metadata = await client.call_tool("get_fonts_metadata", {})
        logger.info(f"폰트 메타데이터:\n{metadata[:500]}...")  # 일부만 출력
    
    logger.info("=== 테스트 완료 ===")

await test_font_metadata()
# Out:
# 2026-01-09 17:13:12 I [ipykernel_launcher:4] - === 폰트 메타데이터 조회 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:12] - 폰트 메타데이터:
# [
#   {
#     "name": "D2coding/D2CodingLigature/D2Coding-Ver1.3.2-20180524-ligature.ttf",
#     "style": "mono",
#     "weight": "regular",
#     "usage": [
#       "code",
#       "technical"
#     ],
#     "tone": [
#       "tech",
#       "modern"
#     ]
#   },
#   {
#     "name": "D2coding/D2CodingLigature/D2CodingBold-Ver1.3.2-20180524-ligature.ttf",
#     "style": "mono",
#     "weight": "bold",
#     "usage": [
#       "code",
#       "technical"
#     ],
#     "tone": [
#       "tech",
#       "modern"
#     ]
#   },
#   {
#     "name": "Na...
# 2026-01-09 17:13:12 I [ipykernel_launcher:14] - === 테스트 완료 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:12] - 폰트 메타데이터:
# [
#   {
#     "name": "D2coding/D2CodingLigature/D2Coding-Ver1.3.2-20180524-ligature.ttf",
#     "style": "mono",
#     "weight": "regular",
#     "usage": [
#       "code",
#       "technical"
#     ],
#     "tone": [
#       "tech",
#       "modern"
#     ]
#   },
#   {
#     "name": "D2coding/D2CodingLigature/D2CodingBold-Ver1.3.2-20180524-ligature.ttf",
#     "style": "mono",
#     "weight": "bold",
#     "usage": [
#       "code",
#       "technical"
#     ],
#     "tone": [
#       "tech",
#       "modern"
#     ]
#   },
#   {
#     "name": "Na...
# 2026-01-09 17:13:12 I [ipykernel_launcher:14] - === 테스트 완료 ===

# %%
# 서버에 등록된 툴 목록 확인
async def check_available_tools():
    """MCP 서버에 등록된 툴 목록 확인"""
    logger.info("=== 서버 등록 툴 확인 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # httpx를 직접 사용하여 /tools 엔드포인트 호출
        response = await client._client.get(f"{MCP_SERVER_URL}/tools")
        response.raise_for_status()
        data = response.json()
        
        tools = data.get("tools", [])
        logger.info(f"등록된 툴 개수: {len(tools)}")
        logger.info("툴 목록:")
        for tool in tools:
            logger.info(f"  - {tool['name']}: {tool['description'][:80]}...")
    
    logger.info("=== 확인 완료 ===")

await check_available_tools()
# Out:
# 2026-01-09 17:13:12 I [ipykernel_launcher:4] - === 서버 등록 툴 확인 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:16] - 등록된 툴 개수: 13
# 2026-01-09 17:13:12 I [ipykernel_launcher:16] - 등록된 툴 개수: 13
# 2026-01-09 17:13:12 I [ipykernel_launcher:17] - 툴 목록:
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_ad_image: 제품 이미지를 기반으로 AI가 전문적인 광고 이미지를 생성합니다. 3단계 파이프라인(배경 생성 → 3D 텍스트 생성 → 최종 합성)을 자동으로 ...
# 2026-01-09 17:13:12 I [ipykernel_launcher:17] - 툴 목록:
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_ad_image: 제품 이미지를 기반으로 AI가 전문적인 광고 이미지를 생성합니다. 3단계 파이프라인(배경 생성 → 3D 텍스트 생성 → 최종 합성)을 자동으로 ...
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - check_generation_status: 비동기로 시작된 광고 생성 작업의 현재 진행 상태를 확인합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - stop_generation: 실행 중인 광고 생성 작업을 강제로 중단합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - check_generation_status: 비동기로 시작된 광고 생성 작업의 현재 진행 상태를 확인합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - stop_generation: 실행 중인 광고 생성 작업을 강제로 중단합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - list_available_fonts: 텍스트 렌더링에 사용할 수 있는 폰트 목록을 반환합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - get_fonts_metadata: 폰트별 상세 메타데이터(스타일, 굵기, 용도, 톤앤매너)를 조회하여 광고 콘텐츠에 적합한 폰트를 선택할 수 있습니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - recommend_font_for_ad: 광고 콘텐츠와 유형에 따라 적합한 폰트를 자동으로 추천합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - list_available_fonts: 텍스트 렌더링에 사용할 수 있는 폰트 목록을 반환합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - get_fonts_metadata: 폰트별 상세 메타데이터(스타일, 굵기, 용도, 톤앤매너)를 조회하여 광고 콘텐츠에 적합한 폰트를 선택할 수 있습니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - recommend_font_for_ad: 광고 콘텐츠와 유형에 따라 적합한 폰트를 자동으로 추천합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - check_server_health: AI 서버의 현재 상태와 시스템 리소스 사용량을 확인합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - get_all_jobs: AI 서버에 등록된 모든 작업 목록을 조회합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - delete_all_jobs: 완료되었거나 실패한 모든 작업을 삭제합니다. 실행/대기 중인 작업은 건너뜁니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - delete_job: 특정 작업을 삭제합니다. 완료/실패한 작업만 삭제 가능합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_background_only: 제품 이미지에 AI 배경만 생성합니다 (Step 1만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_text_asset_only: 3D 텍스트 에셋만 생성합니다 (Step 2만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - compose_final_image: 배경 이미지와 텍스트 에셋을 합성하여 최종 광고 이미지를 생성합니다 (Step 3만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:21] - === 확인 완료 ===
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - check_server_health: AI 서버의 현재 상태와 시스템 리소스 사용량을 확인합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - get_all_jobs: AI 서버에 등록된 모든 작업 목록을 조회합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - delete_all_jobs: 완료되었거나 실패한 모든 작업을 삭제합니다. 실행/대기 중인 작업은 건너뜁니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - delete_job: 특정 작업을 삭제합니다. 완료/실패한 작업만 삭제 가능합니다....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_background_only: 제품 이미지에 AI 배경만 생성합니다 (Step 1만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - generate_text_asset_only: 3D 텍스트 에셋만 생성합니다 (Step 2만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:19] -   - compose_final_image: 배경 이미지와 텍스트 에셋을 합성하여 최종 광고 이미지를 생성합니다 (Step 3만 실행)....
# 2026-01-09 17:13:12 I [ipykernel_launcher:21] - === 확인 완료 ===

# %%
# 2. 세일 광고용 폰트 추천
async def test_font_recommendation_sale():
    """세일 광고용 폰트 추천 테스트"""
    logger.info("=== 세일 광고용 폰트 추천 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # 한글 세일 광고용 폰트 추천
        result = await client.call_tool("recommend_font_for_ad", {
            "text_content": "50% 할인",
            "ad_type": "sale",
            "weight_preference": "bold"
        })
        logger.info(f"추천 결과:\n{result}")
    
    logger.info("=== 테스트 완료 ===")

await test_font_recommendation_sale()
# Out:
# 2026-01-09 17:13:13 I [ipykernel_launcher:4] - === 세일 광고용 폰트 추천 ===
# 2026-01-09 17:13:13 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicBold.ttf
# 스타일: gothic
# 굵기: bold
# 용도: title, body, promotion, sale
# 톤: modern, clean, professional, energetic
# 선택 이유: 광고 유형(sale), 스타일(gothic), 굵기(bold)를 고려하여 선택했습니다.
# 2026-01-09 17:13:13 I [ipykernel_launcher:18] - === 테스트 완료 ===
# 2026-01-09 17:13:13 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔고딕/NanumFontSetup_TTF_GOTHIC/NanumGothicBold.ttf
# 스타일: gothic
# 굵기: bold
# 용도: title, body, promotion, sale
# 톤: modern, clean, professional, energetic
# 선택 이유: 광고 유형(sale), 스타일(gothic), 굵기(bold)를 고려하여 선택했습니다.
# 2026-01-09 17:13:13 I [ipykernel_launcher:18] - === 테스트 완료 ===

# %%
# 3. 프리미엄 광고용 폰트 추천
async def test_font_recommendation_premium():
    """프리미엄 광고용 폰트 추천 테스트"""
    logger.info("=== 프리미엄 광고용 폰트 추천 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # 한글 프리미엄 광고용 폰트 추천
        result = await client.call_tool("recommend_font_for_ad", {
            "text_content": "명품 한정판",
            "ad_type": "premium",
            "tone": "elegant"
        })
        logger.info(f"추천 결과:\n{result}")
    
    logger.info("=== 테스트 완료 ===")

await test_font_recommendation_premium()
# Out:
# 2026-01-09 17:13:13 I [ipykernel_launcher:4] - === 프리미엄 광고용 폰트 추천 ===
# 2026-01-09 17:13:13 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjo.ttf
# 스타일: serif
# 굵기: regular
# 용도: title, body, premium
# 톤: elegant, traditional, sophisticated
# 선택 이유: 광고 유형(premium), 스타일(serif), 굵기(regular)를 고려하여 선택했습니다.
# 2026-01-09 17:13:13 I [ipykernel_launcher:18] - === 테스트 완료 ===
# 2026-01-09 17:13:13 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔명조/NanumFontSetup_TTF_MYUNGJO/NanumMyeongjo.ttf
# 스타일: serif
# 굵기: regular
# 용도: title, body, premium
# 톤: elegant, traditional, sophisticated
# 선택 이유: 광고 유형(premium), 스타일(serif), 굵기(regular)를 고려하여 선택했습니다.
# 2026-01-09 17:13:13 I [ipykernel_launcher:18] - === 테스트 완료 ===

# %%
# 4. 캐주얼 광고용 폰트 추천
async def test_font_recommendation_casual():
    """캐주얼 광고용 폰트 추천 테스트"""
    logger.info("=== 캐주얼 광고용 폰트 추천 ===")
    
    async with MCPClient(
        base_url=MCP_SERVER_URL,
        timeout=30
    ) as client:
        # 손글씨 스타일 폰트 추천
        result = await client.call_tool("recommend_font_for_ad", {
            "text_content": "친구야 놀러와",
            "ad_type": "casual",
            "tone": "friendly"
        })
        logger.info(f"추천 결과:\n{result}")
    
    logger.info("=== 테스트 완료 ===")

await test_font_recommendation_casual()
# Out:
# 2026-01-09 17:13:14 I [ipykernel_launcher:4] - === 캐주얼 광고용 폰트 추천 ===
# 2026-01-09 17:13:14 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenB.ttf
# 스타일: handwriting
# 굵기: bold
# 용도: title, accent, casual
# 톤: friendly, warm, personal
# 선택 이유: 광고 유형(casual), 스타일(handwriting), 굵기(bold)를 고려하여 선택했습니다.
# 2026-01-09 17:13:14 I [ipykernel_launcher:18] - === 테스트 완료 ===
# 2026-01-09 17:13:14 I [ipykernel_launcher:16] - 추천 결과:
# 추천 폰트: 나눔바른펜/NanumFontSetup_TTF_BARUNPEN/NanumBarunpenB.ttf
# 스타일: handwriting
# 굵기: bold
# 용도: title, accent, casual
# 톤: friendly, warm, personal
# 선택 이유: 광고 유형(casual), 스타일(handwriting), 굵기(bold)를 고려하여 선택했습니다.
# 2026-01-09 17:13:14 I [ipykernel_launcher:18] - === 테스트 완료 ===
